# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline
sns.set()

# %%
data = pd.read_csv(r'/Users/alix/Documents/Tableau-Dashboards-/Information_lab/Operations.csv')
data
# Out:
# /var/folders/w_/wfsqzgp956n1415505gs36_h0000gn/T/ipykernel_7234/2705143401.py:1: DtypeWarning: Columns (11,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(r'/Users/alix/Documents/Tableau-Dashboards-/Information_lab/Operations.csv')
#       Identifiant_de_l_etablissement                        Nom_etablissement  \
# 0                           0010093W       Ecole primaire privée Sainte Marie
# 1                           0010106K                        Ecole élémentaire
# 2                           0010107L                           Ecole primaire
# 3                           0010108M                           Ecole primaire
# 4                           0010109N                Ecole primaire Jean Calas
# ...                              ...                                      ...
# 50828                       9870022K  Ecole primaire privée de Ninive-Falaleu
# ...

# %%
data.shape
# Out:
# (50833, 27)

# %%
data.dtypes
# Out:
# Identifiant_de_l_etablissement                    object
# Nom_etablissement                                 object
# Type_etablissement                                object
# Ecole_maternelle                                   int64
# Ecole_elementaire                                  int64
# Statut_public_prive                               object
# libelle_nature                                    object
# Adresse_1                                         object
# Adresse_2                                         object
# Adresse_3                                         object
# Code postal                                        int64
# Code_commune                                      object
# Nom_commune                                       object
# Code_departement                                  object
# Libelle_departement                               object
# Code_academie                                      int64
# ...

# %%
data.libelle_nature.unique()
# Out:
# array(['ECOLE DE NIVEAU ELEMENTAIRE', 'ECOLE MATERNELLE',
#        'ECOLE ELEMENTAIRE D APPLICATION',
#        'ECOLE MATERNELLE D APPLICATION',
#        'ECOLE ELEMENTAIRE ANNEXE D ESPE',
#        'ECOLE DE NIVEAU ELEMENTAIRE SPECIALISEE',
#        'ECOLE MATERNELLE SPECIALISEE', 'ECOLE DE PLEIN AIR',
#        'ECOLE REGIONALE DU PREMIER DEGRE',
#        'ECOLE SANS EFFECTIFS PERMANENTS', 'ECOLE PRIMAIRE FRANCAISE',
#        'ECOLE MATERNELLE ANNEXE D ESPE'], dtype=object)

# %%
data["Code postal"].nunique()
# Out:
# 6405

# %%
data.etat.unique()
# Out:
# array(['OUVERT', 'A FERMER', 'A OUVRIR', nan], dtype=object)

# %%
data.etat.isnull().sum()
# Out:
# 1

# %%
data["Participation_LEGO_Duplo_2017-06"].unique()
# Out:
# array([nan,  1.])

# %%
data["Participation_DISNEY_Roi-Lion_2019-10"].unique()
# Out:
# array([nan,  1.])

# %%
data.isnull().sum()
# Out:
# Identifiant_de_l_etablissement                       0
# Nom_etablissement                                    0
# Type_etablissement                                   0
# Ecole_maternelle                                     0
# Ecole_elementaire                                    0
# Statut_public_prive                                  0
# libelle_nature                                       0
# Adresse_1                                           20
# Adresse_2                                        50186
# Adresse_3                                            0
# Code postal                                          0
# Code_commune                                         0
# Nom_commune                                          0
# Code_departement                                     0
# Libelle_departement                                  0
# Code_academie                                        0
# Libelle_academie                                     0
# ...

# %%
#groupby the data by delivery type
data = data.groupby("Identifiant_de_l_etablissement")["Identifiant_de_l_etablissement"].sum()
data
# Out:
# Identifiant_de_l_etablissement
# 0010093W    0010093W
# 0010106K    0010106K
# 0010107L    0010107L
# 0010108M    0010108M
# 0010109N    0010109N
#               ...
# 9870022K    9870022K
# 9870023L    9870023L
# 9870024M    9870024M
# 9870028S    9870028S
# 9870031V    9870031V
# Name: Identifiant_de_l_etablissement, Length: 50833, dtype: object

# %%
data.head
